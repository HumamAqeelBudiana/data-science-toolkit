# %%
x = 5

if x > 5:
  print("x is greater than 5")
else:
  print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
x=5
print(x)

# %%
print("Hello World")
# Out:
# Hello World

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x=1.5
print(type(x))
# Out:
# <class 'float'>

# %%
x="Hello"
print(type(x))
# Out:
# <class 'str'>

# %%
x="&"
print(type(x))
# Out:
# <class 'str'>
